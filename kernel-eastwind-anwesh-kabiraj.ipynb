# %% [markdown]
# This notebook is explicitly made for tracking the spread of Novel Coronavirus, also known asCOVID-19 (Corona Virus Disease 19)

# %%
import numpy as np 
import matplotlib.pyplot as plt 
import matplotlib.colors as mcolors
import pandas as pd 
import random
import math
import time
from sklearn.linear_model import LinearRegression, BayesianRidge
from sklearn.model_selection import RandomizedSearchCV, train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, mean_absolute_error
import datetime
import operator 
plt.style.use('fivethirtyeight')
# %matplotlib inline

# %% [markdown]
# **Importing data which will update whenever this database is updated**

# %%
confirmed_df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')
deaths_df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv')
recoveries_df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv')
latest_data = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/04-02-2020.csv')

# %%
latest_data.head()
# Out:
#       FIPS     Admin2  Province_State Country_Region          Last_Update  \
# 0  45001.0  Abbeville  South Carolina             US  2020-04-02 23:25:27
# 1  22001.0     Acadia       Louisiana             US  2020-04-02 23:25:27
# 2  51001.0   Accomack        Virginia             US  2020-04-02 23:25:27
# 3  16001.0        Ada           Idaho             US  2020-04-02 23:25:27
# 4  19001.0      Adair            Iowa             US  2020-04-02 23:25:27
#
#          Lat       Long_  Confirmed  Deaths  Recovered  Active  \
# 0  34.223334  -82.461707          6       0          0       0
# 1  30.295065  -92.414197         61       1          0       0
# 2  37.767072  -75.632346         10       0          0       0
# 3  43.452658 -116.241552        312       3          0       0
# 4  41.330756  -94.471059          1       0          0       0
#
#                     Combined_Key
# 0  Abbeville, South Carolina, US
# 1          Acadia, Louisiana, US
# 2         Accomack, Virginia, US
# 3                 Ada, Idaho, US
# 4                Adair, Iowa, US

# %%
confirmed_df.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  3/26/20  3/27/20  3/28/20  3/29/20  \
# 0        0        0        0  ...       94      110      110      120
# 1        0        0        0  ...      174      186      197      212
# 2        0        0        0  ...      367      409      454      511
# 3        0        0        0  ...      224      267      308      334
# 4        0        0        0  ...        4        4        5        7
#
#    3/30/20  3/31/20  4/1/20  4/2/20  4/3/20  4/4/20
# 0      170      174     237     273     281     299
# 1      223      243     259     277     304     333
# 2      584      716     847     986    1171    1251
# 3      370      376     390     428     439     466
# 4        7        7       8       8       8      10
#
# [5 rows x 78 columns]

# %%
cols = confirmed_df.keys()

# %% [markdown]
# **Dates of the outbreak**

# %%
confirmed = confirmed_df.loc[:, cols[4]:cols[-1]]
deaths = deaths_df.loc[:, cols[4]:cols[-1]]
recoveries = recoveries_df.loc[:, cols[4]:cols[-1]]

# %%
dates = confirmed.keys()
world_cases = []
total_deaths = [] 
mortality_rate = []
recovery_rate = [] 
total_recovered = [] 
total_active = [] 
china_cases = [] 
italy_cases = []
us_cases = [] 
spain_cases = [] 
france_cases = [] 

for i in dates:
    confirmed_sum = confirmed[i].sum()
    death_sum = deaths[i].sum()
    recovered_sum = recoveries[i].sum()
    
    # confirmed, deaths, recovered, and active
    world_cases.append(confirmed_sum)
    total_deaths.append(death_sum)
    total_recovered.append(recovered_sum)
    total_active.append(confirmed_sum-death_sum-recovered_sum)
    
    # calculate rates
    mortality_rate.append(death_sum/confirmed_sum)
    recovery_rate.append(recovered_sum/confirmed_sum)

    # case studies 
    china_cases.append(confirmed_df[confirmed_df['Country/Region']=='China'][i].sum())
    italy_cases.append(confirmed_df[confirmed_df['Country/Region']=='Italy'][i].sum())
    us_cases.append(confirmed_df[confirmed_df['Country/Region']=='US'][i].sum())
    spain_cases.append(confirmed_df[confirmed_df['Country/Region']=='Spain'][i].sum())
    france_cases.append(confirmed_df[confirmed_df['Country/Region']=='France'][i].sum())

# %% [markdown]
# **Daily Increase**

# %%
def daily_increase(data):
    d = [] 
    for i in range(len(data)):
        if i == 0:
            d.append(data[0])
        else:
            d.append(data[i]-data[i-1])
    return d 

world_daily_increase = daily_increase(world_cases)
china_daily_increase = daily_increase(china_cases)
italy_daily_increase = daily_increase(italy_cases)
us_daily_increase = daily_increase(us_cases)
spain_daily_increase = daily_increase(spain_cases)
france_daily_increase = daily_increase(france_cases)

# %%
days_since_1_22 = np.array([i for i in range(len(dates))]).reshape(-1, 1)
world_cases = np.array(world_cases).reshape(-1, 1)
total_deaths = np.array(total_deaths).reshape(-1, 1)
total_recovered = np.array(total_recovered).reshape(-1, 1)

# %% [markdown]
# **Forecast**

# %%
days_in_future = 10
future_forcast = np.array([i for i in range(len(dates)+days_in_future)]).reshape(-1, 1)
adjusted_dates = future_forcast[:-10]

# %% [markdown]
# **Integer to date time**

# %%
start = '1/22/2020'
start_date = datetime.datetime.strptime(start, '%m/%d/%Y')
future_forcast_dates = []
for i in range(len(future_forcast)):
    future_forcast_dates.append((start_date + datetime.timedelta(days=i)).strftime('%m/%d/%Y'))

# %%
X_train_confirmed, X_test_confirmed, y_train_confirmed, y_test_confirmed = train_test_split(days_since_1_22, world_cases, test_size=0.10, shuffle=False)

# %% [markdown]
# **Model for prediciting cases of COVID 19 using vector machine, linear regression and bayseian ridge**

# %%
# c = [0.01, 0.1, 1]
# gamma = [0.01, 0.1, 1]
# epsilon = [0.01, 0.1, 1]
# shrinking = [True, False]
# degree = [3, 4, 5, 6, 7]

# svm_grid = {'C': c, 'gamma' : gamma, 'epsilon': epsilon, 'shrinking' : shrinking, 'degree': degree}

# svm = SVR(kernel='poly')
# svm_search = RandomizedSearchCV(svm, svm_grid, scoring='neg_mean_squared_error', cv=3, return_train_score=True, n_jobs=-1, n_iter=30, verbose=1)
# svm_search.fit(X_train_confirmed, y_train_confirmed)

# %%
# svm_search.best_params_

# %%
# svm_confirmed = svm_search.best_estimator_
svm_confirmed = SVR(shrinking=True, kernel='poly',gamma=0.01, epsilon=1,degree=7, C=0.1)
svm_confirmed.fit(X_train_confirmed, y_train_confirmed)
svm_pred = svm_confirmed.predict(future_forcast)
# Out:
# /opt/conda/lib/python3.6/site-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
# check against testing data
svm_test_pred = svm_confirmed.predict(X_test_confirmed)
plt.plot(y_test_confirmed)
plt.plot(svm_test_pred)
plt.legend(['Test Data', 'SVM Predictions'])
print('MAE:', mean_absolute_error(svm_test_pred, y_test_confirmed))
print('MSE:',mean_squared_error(svm_test_pred, y_test_confirmed))
# Out:
# MAE: 21654.86652698985
# MSE: 590401257.896022

# %%
# transform our data for polynomial regression
poly = PolynomialFeatures(degree=5)
poly_X_train_confirmed = poly.fit_transform(X_train_confirmed)
poly_X_test_confirmed = poly.fit_transform(X_test_confirmed)
poly_future_forcast = poly.fit_transform(future_forcast)

# %%
# polynomial regression
linear_model = LinearRegression(normalize=True, fit_intercept=False)
linear_model.fit(poly_X_train_confirmed, y_train_confirmed)
test_linear_pred = linear_model.predict(poly_X_test_confirmed)
linear_pred = linear_model.predict(poly_future_forcast)
print('MAE:', mean_absolute_error(test_linear_pred, y_test_confirmed))
print('MSE:',mean_squared_error(test_linear_pred, y_test_confirmed))
# Out:
# MAE: 65333.58630802311
# MSE: 6827956485.033843

# %%
print(linear_model.coef_)
# Out:
# [[-2.31367585e+02  1.57843914e+02  1.01126696e+02  5.36996037e+00
#   -3.07888201e-01  3.59532963e-03]]

# %%
plt.plot(y_test_confirmed)
plt.plot(test_linear_pred)
plt.legend(['Test Data', 'Polynomial Regression Predictions'])

# %%
# bayesian ridge polynomial regression
tol = [1e-4, 1e-3, 1e-2]
alpha_1 = [1e-7, 1e-6, 1e-5, 1e-4]
alpha_2 = [1e-7, 1e-6, 1e-5, 1e-4]
lambda_1 = [1e-7, 1e-6, 1e-5, 1e-4]
lambda_2 = [1e-7, 1e-6, 1e-5, 1e-4]

bayesian_grid = {'tol': tol, 'alpha_1': alpha_1, 'alpha_2' : alpha_2, 'lambda_1': lambda_1, 'lambda_2' : lambda_2}

bayesian = BayesianRidge(fit_intercept=False, normalize=True)
bayesian_search = RandomizedSearchCV(bayesian, bayesian_grid, scoring='neg_mean_squared_error', cv=3, return_train_score=True, n_jobs=-1, n_iter=40, verbose=1)
bayesian_search.fit(poly_X_train_confirmed, y_train_confirmed)
# Out:
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  81 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    1.4s finished
# /opt/conda/lib/python3.6/site-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# RandomizedSearchCV(cv=3, error_score=nan,
#                    estimator=BayesianRidge(alpha_1=1e-06, alpha_2=1e-06,
#                                            alpha_init=None, compute_score=False,
#                                            copy_X=True, fit_intercept=False,
#                                            lambda_1=1e-06, lambda_2=1e-06,
#                                            lambda_init=None, n_iter=300,
#                                            normalize=True, tol=0.001,
#                                            verbose=False),
#                    iid='deprecated', n_iter=40, n_jobs=-1,
#                    param_distributions={'alpha_1': [1e-07, 1e-06, 1e-05,
#                                                     0.0001],
#                                         'alpha_2': [1e-07, 1e-06, 1e-05,
#                                                     0.0001],
#                                         'lambda_1': [1e-07, 1e-06, 1e-05,
#                                                      0.0001],
#                                         'lambda_2': [1e-07, 1e-06, 1e-05,
#                                                      0.0001],
#                                         'tol': [0.0001, 0.001, 0.01]},
#                    pre_dispatch='2*n_jobs', random_state=None, refit=True,
#                    return_train_score=True, scoring='neg_mean_squared_error',
#                    verbose=1)

# %%
bayesian_search.best_params_
# Out:
# {'tol': 0.0001,
#  'lambda_2': 1e-07,
#  'lambda_1': 0.0001,
#  'alpha_2': 1e-07,
#  'alpha_1': 1e-06}

# %%
bayesian_confirmed = bayesian_search.best_estimator_
test_bayesian_pred = bayesian_confirmed.predict(poly_X_test_confirmed)
bayesian_pred = bayesian_confirmed.predict(poly_future_forcast)
print('MAE:', mean_absolute_error(test_bayesian_pred, y_test_confirmed))
print('MSE:',mean_squared_error(test_bayesian_pred, y_test_confirmed))
# Out:
# MAE: 65854.86411949835
# MSE: 6929758896.236263

# %%
plt.plot(y_test_confirmed)
plt.plot(test_bayesian_pred)
plt.legend(['Test Data', 'Bayesian Ridge Polynomial Predictions'])

# %% [markdown]
# Graphing confirmed cases,active cases,deaths,recoveries,mortality rate and recovery rate

# %%
adjusted_dates = adjusted_dates.reshape(1, -1)[0]
plt.figure(figsize=(16, 9))
plt.plot(adjusted_dates, world_cases, color='red')
plt.title('Number of COVID-19 Cases Over Time', size=30)
plt.xlabel('Days after 22nd JAN--2020', size=30)
plt.ylabel('Number of Cases', size=30)
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

# %%
plt.figure(figsize=(16, 9))
plt.bar(adjusted_dates, world_daily_increase, color='red')
plt.title('World Daily Increases in Confirmed Cases', size=30)
plt.xlabel('Days after 22nd JAN--2020', size=30)
plt.ylabel('Number of Cases', size=30)
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

# %%
plt.figure(figsize=(16, 9))
plt.plot(adjusted_dates, np.log10(world_cases), color='red')
plt.title('Log of # of Covid-19 Cases Over Time', size=30)
plt.xlabel('Days after 22nd JAN--2020', size=30)
plt.ylabel('Number of Cases', size=30)
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

# %%
plt.figure(figsize=(16, 9))
plt.bar(adjusted_dates, us_daily_increase, color='red')
plt.title('US Daily Increases in Confirmed Cases', size=30)
plt.xlabel('Days after 22nd JAN--2020', size=30)
plt.ylabel('Number of Cases', size=30)
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

# %%
plt.figure(figsize=(16, 9))
plt.bar(adjusted_dates, italy_daily_increase, color='red')
plt.title('Italy Daily Increases in Confirmed Cases', size=30)
plt.xlabel('Days after 22nd JAN--2020', size=30)
plt.ylabel('Number of Cases', size=30)
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

# %%
plt.figure(figsize=(16, 9))
plt.bar(adjusted_dates, spain_daily_increase, color='red')
plt.title('Spain Daily Increases in Confirmed Cases', size=30)
plt.xlabel('Days after 22nd JAN--2020', size=30)
plt.ylabel('Number of Cases', size=30)
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

# %%
plt.figure(figsize=(16, 9))
plt.bar(adjusted_dates, china_daily_increase, color='red')
plt.title('China Daily Increases in Confirmed Cases', size=30)
plt.xlabel('Days after 22nd JAN--2020', size=30)
plt.ylabel('Number of Cases', size=30)
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

# %%
plt.figure(figsize=(16, 9))
plt.bar(adjusted_dates, france_daily_increase, color='red')
plt.title('France Daily Increases in Confirmed Cases', size=30)
plt.xlabel('Days after 22nd JAN--2020', size=30)
plt.ylabel('Number of Cases', size=30)
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

# %%
plt.figure(figsize=(16, 9))
plt.plot(adjusted_dates, china_cases)
plt.plot(adjusted_dates, italy_cases)
plt.plot(adjusted_dates, us_cases)
plt.plot(adjusted_dates, spain_cases)
plt.plot(adjusted_dates, france_cases)
plt.title('Number of Covid-19 Cases', size=30)
plt.xlabel('Days after 22nd JAN--2020', size=30)
plt.ylabel('Number of Cases', size=30)
plt.legend(['China', 'Italy', 'US', 'Spain', 'France'], prop={'size': 20})
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

# %%
plt.figure(figsize=(16, 9))
plt.plot(adjusted_dates, world_cases, color='red')
plt.plot(future_forcast, svm_pred, linestyle='dashed', color='purple')
plt.title('Number of Covid-19 Cases Over Time', size=30)
plt.xlabel('Days after 22nd JAN--2020', size=30)
plt.ylabel('Number of Cases', size=30)
plt.legend(['Confirmed Cases', 'SVM predictions'], prop={'size': 20})
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

# %%
plt.figure(figsize=(16, 9))
plt.plot(adjusted_dates, world_cases, color='red')
plt.plot(future_forcast, linear_pred, linestyle='dashed', color='orange')
plt.title('Number of Covid-19 Cases Over Time', size=30)
plt.xlabel('Days after 22nd JAN--2020', size=30)
plt.ylabel('Number of Cases', size=30)
plt.legend(['Confirmed Cases', 'Polynomial Regression Predictions'], prop={'size': 20})
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

# %%
plt.figure(figsize=(16, 9))
plt.plot(adjusted_dates, world_cases, color='red')
plt.plot(future_forcast, bayesian_pred, linestyle='dashed', color='green')
plt.title('Number of Covid-19 Cases Over Time', size=30)
plt.xlabel('Time', size=30)
plt.ylabel('Number of Cases', size=30)
plt.legend(['Confirmed Cases', 'Polynomial Bayesian Ridge Regression Predictions'], prop={'size': 20})
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

# %%
# Future predictions using SVM 
print('SVM future predictions:')
set(zip(future_forcast_dates[-10:], np.round(svm_pred[-10:])))
# Out:
# SVM future predictions:
# {('04/05/2020', 1326815.0),
#  ('04/06/2020', 1452839.0),
#  ('04/07/2020', 1589359.0),
#  ('04/08/2020', 1737093.0),
#  ('04/09/2020', 1896799.0),
#  ('04/10/2020', 2069274.0),
#  ('04/11/2020', 2255357.0),
#  ('04/12/2020', 2455933.0),
#  ('04/13/2020', 2671930.0),
#  ('04/14/2020', 2904323.0)}

# %%
# Future predictions using Polynomial Regression 
linear_pred = linear_pred.reshape(1,-1)[0]
print('Polynomial regression future predictions:')
set(zip(future_forcast_dates[-10:], np.round(linear_pred[-10:])))
# Out:
# Polynomial regression future predictions:
# {('04/05/2020', 1486803.0),
#  ('04/06/2020', 1636007.0),
#  ('04/07/2020', 1797385.0),
#  ('04/08/2020', 1971642.0),
#  ('04/09/2020', 2159505.0),
#  ('04/10/2020', 2361732.0),
#  ('04/11/2020', 2579102.0),
#  ('04/12/2020', 2812425.0),
#  ('04/13/2020', 3062536.0),
#  ('04/14/2020', 3330297.0)}

# %%
# Future predictions using Linear Regression 
print('Ridge regression future predictions:')
set(zip(future_forcast_dates[-10:], np.round(bayesian_pred[-10:])))
# Out:
# Ridge regression future predictions:
# {('04/05/2020', 1488003.0),
#  ('04/06/2020', 1637398.0),
#  ('04/07/2020', 1798984.0),
#  ('04/08/2020', 1973466.0),
#  ('04/09/2020', 2161575.0),
#  ('04/10/2020', 2364066.0),
#  ('04/11/2020', 2581722.0),
#  ('04/12/2020', 2815353.0),
#  ('04/13/2020', 3065794.0),
#  ('04/14/2020', 3333908.0)}

# %%
plt.figure(figsize=(16, 9))
plt.plot(adjusted_dates, total_active, color='purple')
plt.title('Number of Covid-19 Active Cases Over Time', size=30)
plt.xlabel('Days after 22nd JAN--2020', size=30)
plt.ylabel('Number of Active Cases', size=30)
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

# %%
plt.figure(figsize=(16, 9))
plt.plot(adjusted_dates, total_deaths, color='red')
plt.title('Number of Covid-19 Deaths Over Time', size=30)
plt.xlabel('Days after 22nd JAN--2020', size=30)
plt.ylabel('Number of Deaths', size=30)
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

# %%
mean_mortality_rate = np.mean(mortality_rate)
plt.figure(figsize=(16, 9))
plt.plot(adjusted_dates, mortality_rate, color='orange')
plt.axhline(y = mean_mortality_rate,linestyle='--', color='black')
plt.title('Mortality Rate of Covid-19 Over Time', size=30)
plt.legend(['mortality rate', 'y='+str(mean_mortality_rate)], prop={'size': 20})
plt.xlabel('Days after 22nd JAN--2020', size=30)
plt.ylabel('Mortality Rate', size=30)
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

# %%
plt.figure(figsize=(16, 9))
plt.plot(adjusted_dates, total_recovered, color='green')
plt.title('Number of Covid-19 Cases Recovered Over Time', size=30)
plt.xlabel('Days after 22nd JAN--2020', size=30)
plt.ylabel('Number of Cases', size=30)
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

# %%
mean_recovery_rate = np.mean(recovery_rate)
plt.figure(figsize=(16, 9))
plt.plot(adjusted_dates, recovery_rate, color='blue')
plt.axhline(y = mean_recovery_rate,linestyle='--', color='black')
plt.title('Recovery Rate of Covid-19s Over Time', size=30)
plt.legend(['recovery rate', 'y='+str(mean_recovery_rate)], prop={'size': 20})
plt.xlabel('Days after 22nd JAN--2020', size=30)
plt.ylabel('Recovery Rate', size=30)
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

# %% [markdown]
# Graphs plotting death againnst recoveries

# %%
plt.figure(figsize=(16, 9))
plt.plot(adjusted_dates, total_deaths, color='r')
plt.plot(adjusted_dates, total_recovered, color='green')
plt.legend(['death', 'recoveries'], loc='best', fontsize=20)
plt.title('Number of Covid-19 Cases', size=30)
plt.xlabel('Days after 22nd JAN--2020', size=30)
plt.ylabel('Number of Cases', size=30)
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

# %%
plt.figure(figsize=(16, 9))
plt.plot(total_recovered, total_deaths)
plt.title('Number of Covid-19 Deaths vs. # of Covid-19 Recoveries', size=30)
plt.xlabel('Number of Covid-19 Recoveries', size=30)
plt.ylabel('Number of Covid-19 Deaths', size=30)
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

# %% [markdown]
# Information of countries with COVID- 19

# %%
unique_countries =  list(latest_data['Country_Region'].unique())

# %%
country_confirmed_cases = []
country_death_cases = [] 
country_active_cases = []
country_recovery_cases = []
country_mortality_rate = [] 

no_cases = []
for i in unique_countries:
    cases = latest_data[latest_data['Country_Region']==i]['Confirmed'].sum()
    if cases > 0:
        country_confirmed_cases.append(cases)
    else:
        no_cases.append(i)
        
for i in no_cases:
    unique_countries.remove(i)
    
# sort countries by the number of confirmed cases
unique_countries = [k for k, v in sorted(zip(unique_countries, country_confirmed_cases), key=operator.itemgetter(1), reverse=True)]
for i in range(len(unique_countries)):
    country_confirmed_cases[i] = latest_data[latest_data['Country_Region']==unique_countries[i]]['Confirmed'].sum()
    country_death_cases.append(latest_data[latest_data['Country_Region']==unique_countries[i]]['Deaths'].sum())
    country_recovery_cases.append(latest_data[latest_data['Country_Region']==unique_countries[i]]['Recovered'].sum())
    country_active_cases.append(country_confirmed_cases[i] - country_death_cases[i] - country_recovery_cases[i])
    country_mortality_rate.append(country_death_cases[i]/country_confirmed_cases[i])

# %%
country_df = pd.DataFrame({'Country Name': unique_countries, 'Number of Confirmed Cases': country_confirmed_cases,
                          'Number of Deaths': country_death_cases, 'Number of Recoveries' : country_recovery_cases, 
                          'Number of Active Cases' : country_active_cases,
                          'Mortality Rate': country_mortality_rate})
# number of cases per country/region

country_df.style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
#     #T_ad9b1846_7781_11ea_974d_0242ac130202row0_col1 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_ad9b1846_7781_11ea_974d_0242ac130202row0_col2 {
#             background-color:  #fc8161;
#             color:  #000000;
#         }    #T_ad9b1846_7781_11ea_974d_0242ac130202row0_col3 {
#             background-color:  #fee1d4;
#             color:  #000000;
#         }    #T_ad9b1846_7781_11ea_974d_0242ac130202row0_col4 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_ad9b1846_7781_11ea_974d_0242ac130202row0_col5 {
#             background-color:  #fee5d9;
#             color:  #000000;
#         }    #T_ad9b1846_7781_11ea_974d_0242ac130202row1_col1 {
#             background-color:  #fb7252;
#             color:  #000000;
#         }    #T_ad9b1846_7781_11ea_974d_0242ac130202row1_col2 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_ad9b1846_7781_11ea_974d_0242ac130202row1_col3 {
#             background-color:  #fcbea5;
#             color:  #000000;
#         }    #T_ad9b1846_7781_11ea_974d_0242ac130202row1_col4 {
#             background-color:  #fc9576;
#             color:  #000000;
#         }    #T_ad9b1846_7781_11ea_974d_0242ac130202row1_col5 {
#             background-color:  #fb7050;
#             color:  #000000;
#         }    #T_ad9b1846_7781_11ea_974d_0242ac130202row2_col1 {
#             background-color:  #fb7757;
#             color:  #000000;
#         }    #T_ad9b1846_7781_11ea_974d_0242ac130202row2_col2 {
#             background-color:  #cc191e;
#             color:  #f1f1f1;
#         }    #T_ad9b1846_7781_11ea_974d_0242ac130202row2_col3 {
#             background-color:  #fc9b7c;
#             color:  #000000;
#         }    #T_ad9b1846_7781_11ea_974d_0242ac130202row2_col4 {
#             background-color:  #fca285;
#             color:  #000000;
#         }    #T_ad9b1846_7781_11ea_974d_0242ac130202row2_col5 {
#             background-color:  #fc9474;
#             color:  #000000;
#         }    #T_ad9b1846_7781_11ea_974d_0242ac130202row3_col1 {
#             background-color:  #fc9b7c;
#             color:  #000000;
#         }    #T_ad9b1846_7781_11ea_974d_0242ac130202row3_col2 {
#             background-color:  #fee8dd;
#             color:  #000000;
#         }    #T_ad9b1846_7781_11ea_974d_0242ac130202row3_col3 {
#             background-color:  #fcad90;
#             color:  #000000;
#         }    #T_ad9b1846_7781_11ea_974d_0242ac130202row3_col4 {
#             background-color:  #fcb69b;
#             color:  #000000;
#         }    #T_ad9b1846_7781_11ea_974d_0242ac130202row3_col5 {
#             background-color:  #ffece4;
#             color:  #000000;
#         }    #T_ad9b1846_7781_11ea_974d_0242ac130202row4_col1 {
#             background-color:  #fc9e80;
#             color:  #000000;
#         }    #T_ad9b1846_7781_11ea_974d_0242ac130202row4_col2 {
#             background-color:  #fcbea5;
#             color:  #000000;
#         }    #T_ad9b1846_7781_11ea_974d_0242ac130202row4_col3 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_ad9b1846_7781_11ea_974d_0242ac130202row4_col4 {
#             background-color:  #fff4ee;
#             color:  #000000;
#         }    #T_ad9b1846_7781_11ea_974d_0242ac130202row4_col5 {
#             background-color:  #fdd5c4;
#             color:  #000000;
#         }    #T_ad9b1846_7781_11ea_974d_0242ac130202row5_col1 {
#             background-color:  #fcbca2;
#             color:  #000000;
#         }    #T_ad9b1846_7781_11ea_974d_0242ac130202row5_col2 {
#             background-color:  #fc8e6e;
#             color:  #000000;
#         }    #T_ad9b1846_7781_11ea_974d_0242ac130202row5_col3 {
#             background-color:  #fdd5c4;
#             color:  #000000;
#         }    #T_ad9b1846_7781_11ea_974d_0242ac130202row5_col4 {
#             background-color:  #fdcebb;
#             color:  #000000;
#         }    #T_ad9b1846_7781_11ea_974d_0242ac130202row5_col5 {
#             background-color:  #fc9777;
#             color:  #000000;
#         }    #T_ad9b1846_7781_11ea_974d_0242ac130202row6_col1 {
#             background-color:  #fdc7b2;
#             color:  #000000;
#         }    #T_ad9b1846_7781_11ea_974d_0242ac130202row6_col2 {
#             background-color:  #fcc2aa;
#             color:  #000000;
#         }    #T_ad9b1846_7781_11ea_974d_0242ac130202row6_col3 {
#             background-color:  #fdc5ae;
#             color:  #000000;
#         }    #T_ad9b1846_7781_11ea_974d_0242ac130202row6_col4 {
#             background-color:  #fedecf;
#             color:  #000000;
#         }    #T_ad9b1846_7781_11ea_974d_0242ac130202row6_col5 {
#             background-color:  #fcbba1;
#             color:  #000000;
#         }    #T_ad9b1846_7781_11ea_974d_0242ac130202row7_col1 {
#             background-color:  #fedccd;
#             color:  #000000;
#         }    #T_ad9b1846_7781_11ea_974d_0242ac130202row7_col2 {
#             background-color:  #fdc7b2;
#             color:  #000000;
#         }    #T_ad9b1846_7781_11ea_974d_0242ac130202row7_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_ad9b1846_7781_11ea_974d_0242ac130202row7_col4 {
#             background-color:  #fedecf;
#             color:  #000000;
#         }    #T_ad9b1846_7781_11ea_974d_0242ac130202row7_col5 {
#             background-color:  #fc9d7f;
#             color:  #000000;
#         }    #T_ad9b1846_7781_11ea_974d_0242ac130202row8_col1 {
#             background-color:  #fee8de;
#             color:  #000000;
#         }    #T_ad9b1846_7781_11ea_974d_0242ac130202row8_col2 {
#             background-color:  #ffefe8;
#             color:  #000000;
#         }    #T_ad9b1846_7781_11ea_974d_0242ac130202row8_col3 {
#             background-color:  #ffece4;
#             color:  #000000;
#         }    #T_ad9b1846_7781_11ea_974d_0242ac130202row8_col4 {
#             background-color:  #ffebe2;
#             color:  #000000;
#         }    #T_ad9b1846_7781_11ea_974d_0242ac130202row8_col5 {
#             background-color:  #fee2d5;
#             color:  #000000;
#         }    #T_ad9b1846_7781_11ea_974d_0242ac130202row9_col1 {
#             background-color:  #fee8de;
#             color:  #000000;
#         }    #T_ad9b1846_7781_11ea_974d_0242ac130202row9_col2 {
#             background-color:  #fff1ea;
#             color:  #000000;
#         }    #T_ad9b1846_7781_11ea_974d_0242ac130202row9_col3 {
#             background-color:  #fff4ef;
#             color:  #000000;
#         }    #T_ad9b1846_7781_11ea_974d_0242ac130202row9_col4 {
#             background-color:  #fee8de;
#             color:  #000000;
#         }    #T_ad9b1846_7781_11ea_974d_0242ac130202row9_col5 {
#             background-color:  #fee8dd;
#             color:  #000000;
#         }    #T_ad9b1846_7781_11ea_974d_0242ac130202row10_col1 {
#             background-color:  #feeae1;
#             color:  #000000;
#         }    #T_ad9b1846_7781_11ea_974d_0242ac130202row10_col2 {
#             background-color:  #fee9df;
#             color:  #000000;
#         }    #T_ad9b1846_7781_11ea_974d_0242ac130202row10_col3 {
#             background-color:  #fff0e8;
#             color:  #000000;
#         }    #T_ad9b1846_7781_11ea_974d_0242ac130202row10_col4 {
#             background-color:  #ffece4;
#             color:  #000000;
#         }    #T_ad9b1846_7781_11ea_974d_0242ac130202row10_col5 {
#             background-color:  #fcb79c;
#             color:  #000000;
#         }    #T_ad9b1846_7781_11ea_974d_0242ac130202row11_col1 {
#             background-color:  #ffebe2;
#             color:  #000000;
#         }    #T_ad9b1846_7781_11ea_974d_0242ac130202row11_col2 {
#             background-color:  #fee5d9;
#             color:  #000000;
#         }    #T_ad9b1846_7781_11ea_974d_0242ac130202row11_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_ad9b1846_7781_11ea_974d_0242ac130202row11_col4 {
#             background-color:  #ffece3;
#             color:  #000000;
#         }    #T_ad9b1846_7781_11ea_974d_0242ac130202row11_col5 {
#             background-color:  #fc9777;
#             color:  #0

# %%
unique_provinces =  list(latest_data['Province_State'].unique())

# %%
province_confirmed_cases = []
province_country = [] 
province_death_cases = [] 
province_recovery_cases = []
province_mortality_rate = [] 

no_cases = [] 
for i in unique_provinces:
    cases = latest_data[latest_data['Province_State']==i]['Confirmed'].sum()
    if cases > 0:
        province_confirmed_cases.append(cases)
    else:
        no_cases.append(i)
 
# remove areas with no confirmed cases
for i in no_cases:
    unique_provinces.remove(i)
    
unique_provinces = [k for k, v in sorted(zip(unique_provinces, province_confirmed_cases), key=operator.itemgetter(1), reverse=True)]
for i in range(len(unique_provinces)):
    province_confirmed_cases[i] = latest_data[latest_data['Province_State']==unique_provinces[i]]['Confirmed'].sum()
    province_country.append(latest_data[latest_data['Province_State']==unique_provinces[i]]['Country_Region'].unique()[0])
    province_death_cases.append(latest_data[latest_data['Province_State']==unique_provinces[i]]['Deaths'].sum())
    province_recovery_cases.append(latest_data[latest_data['Province_State']==unique_provinces[i]]['Recovered'].sum())
    province_mortality_rate.append(province_death_cases[i]/province_confirmed_cases[i])

# %%
# number of cases per province/state/city
province_df = pd.DataFrame({'Province/State Name': unique_provinces, 'Country': province_country, 'Number of Confirmed Cases': province_confirmed_cases,
                          'Number of Deaths': province_death_cases, 'Number of Recoveries' : province_recovery_cases,
                          'Mortality Rate': province_mortality_rate})
# number of cases per country/region

province_df.style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
#     #T_ae6c35ca_7781_11ea_974d_0242ac130202row0_col2 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_ae6c35ca_7781_11ea_974d_0242ac130202row0_col3 {
#             background-color:  #ce1a1e;
#             color:  #f1f1f1;
#         }    #T_ae6c35ca_7781_11ea_974d_0242ac130202row0_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_ae6c35ca_7781_11ea_974d_0242ac130202row0_col5 {
#             background-color:  #fed8c7;
#             color:  #000000;
#         }    #T_ae6c35ca_7781_11ea_974d_0242ac130202row1_col2 {
#             background-color:  #d01d1f;
#             color:  #f1f1f1;
#         }    #T_ae6c35ca_7781_11ea_974d_0242ac130202row1_col3 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_ae6c35ca_7781_11ea_974d_0242ac130202row1_col4 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_ae6c35ca_7781_11ea_974d_0242ac130202row1_col5 {
#             background-color:  #fcb095;
#             color:  #000000;
#         }    #T_ae6c35ca_7781_11ea_974d_0242ac130202row2_col2 {
#             background-color:  #fcb398;
#             color:  #000000;
#         }    #T_ae6c35ca_7781_11ea_974d_0242ac130202row2_col3 {
#             background-color:  #fdd4c2;
#             color:  #000000;
#         }    #T_ae6c35ca_7781_11ea_974d_0242ac130202row2_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_ae6c35ca_7781_11ea_974d_0242ac130202row2_col5 {
#             background-color:  #fee0d2;
#             color:  #000000;
#         }    #T_ae6c35ca_7781_11ea_974d_0242ac130202row3_col2 {
#             background-color:  #fee2d5;
#             color:  #000000;
#         }    #T_ae6c35ca_7781_11ea_974d_0242ac130202row3_col3 {
#             background-color:  #fedfd0;
#             color:  #000000;
#         }    #T_ae6c35ca_7781_11ea_974d_0242ac130202row3_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_ae6c35ca_7781_11ea_974d_0242ac130202row3_col5 {
#             background-color:  #fcc1a8;
#             color:  #000000;
#         }    #T_ae6c35ca_7781_11ea_974d_0242ac130202row4_col2 {
#             background-color:  #fee2d5;
#             color:  #000000;
#         }    #T_ae6c35ca_7781_11ea_974d_0242ac130202row4_col3 {
#             background-color:  #fee8de;
#             color:  #000000;
#         }    #T_ae6c35ca_7781_11ea_974d_0242ac130202row4_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_ae6c35ca_7781_11ea_974d_0242ac130202row4_col5 {
#             background-color:  #fedfd0;
#             color:  #000000;
#         }    #T_ae6c35ca_7781_11ea_974d_0242ac130202row5_col2 {
#             background-color:  #fee5d8;
#             color:  #000000;
#         }    #T_ae6c35ca_7781_11ea_974d_0242ac130202row5_col3 {
#             background-color:  #fee5d9;
#             color:  #000000;
#         }    #T_ae6c35ca_7781_11ea_974d_0242ac130202row5_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_ae6c35ca_7781_11ea_974d_0242ac130202row5_col5 {
#             background-color:  #fdcab5;
#             color:  #000000;
#         }    #T_ae6c35ca_7781_11ea_974d_0242ac130202row6_col2 {
#             background-color:  #fee5d9;
#             color:  #000000;
#         }    #T_ae6c35ca_7781_11ea_974d_0242ac130202row6_col3 {
#             background-color:  #ffece4;
#             color:  #000000;
#         }    #T_ae6c35ca_7781_11ea_974d_0242ac130202row6_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_ae6c35ca_7781_11ea_974d_0242ac130202row6_col5 {
#             background-color:  #fee3d7;
#             color:  #000000;
#         }    #T_ae6c35ca_7781_11ea_974d_0242ac130202row7_col2 {
#             background-color:  #fee5d9;
#             color:  #000000;
#         }    #T_ae6c35ca_7781_11ea_974d_0242ac130202row7_col3 {
#             background-color:  #ffede5;
#             color:  #000000;
#         }    #T_ae6c35ca_7781_11ea_974d_0242ac130202row7_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_ae6c35ca_7781_11ea_974d_0242ac130202row7_col5 {
#             background-color:  #fee4d8;
#             color:  #000000;
#         }    #T_ae6c35ca_7781_11ea_974d_0242ac130202row8_col2 {
#             background-color:  #fee7dc;
#             color:  #000000;
#         }    #T_ae6c35ca_7781_11ea_974d_0242ac130202row8_col3 {
#             background-color:  #ffece4;
#             color:  #000000;
#         }    #T_ae6c35ca_7781_11ea_974d_0242ac130202row8_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_ae6c35ca_7781_11ea_974d_0242ac130202row8_col5 {
#             background-color:  #fee0d2;
#             color:  #000000;
#         }    #T_ae6c35ca_7781_11ea_974d_0242ac130202row9_col2 {
#             background-color:  #fee8dd;
#             color:  #000000;
#         }    #T_ae6c35ca_7781_11ea_974d_0242ac130202row9_col3 {
#             background-color:  #fff0e9;
#             color:  #000000;
#         }    #T_ae6c35ca_7781_11ea_974d_0242ac130202row9_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_ae6c35ca_7781_11ea_974d_0242ac130202row9_col5 {
#             background-color:  #fee8de;
#             color:  #000000;
#         }    #T_ae6c35ca_7781_11ea_974d_0242ac130202row10_col2 {
#             background-color:  #feeae0;
#             color:  #000000;
#         }    #T_ae6c35ca_7781_11ea_974d_0242ac130202row10_col3 {
#             background-color:  #fee7dc;
#             color:  #000000;
#         }    #T_ae6c35ca_7781_11ea_974d_0242ac130202row10_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_ae6c35ca_7781_11ea_974d_0242ac130202row10_col5 {
#             background-color:  #fcb99f;
#             color:  #000000;
#         }    #T_ae6c35ca_7781_11ea_974d_0242ac130202row11_col2 {
#             background-color:  #ffebe2;
#             color:  #000000;
#         }    #T_ae6c35ca_7781_11ea_974d_0242ac130202row11_col3 {
#             background-color:  #fff4ee;
#             color:  #000000;
#         }    #T_ae6c35ca_7781_11ea_974d_0242ac130202row11_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_ae6c35ca_7781_11ea_974d_0242ac130202row11_col5 {
#             background-color:  #ffeee7;
#             color:  #000000;
#         }    #T_ae6c35ca_7781_11ea_974d_0242ac130202row12_col2 {
#             background-color:  #ffece3;
#             color:  #000000;
#         }    #T_ae6c35ca_7781_11ea_974d_0242ac130202row12_col3 {
#             background-color:  #ffece4;
#             color:  #000000;
#         }    #T_ae6c35ca_7781_11ea_974d_0242ac130202row12_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_ae6c35ca_7781_11ea_974d_0242ac130202row12_col5 {
#             background-color:  #fdd0bc;
#             color:  #000000;
#         }    #T_ae6c35ca_7781_11ea_974d_0242ac130202row13_col2 {
#             background-color:  #ffece3;
#             color:  #000000;
#         }    #T_ae6c35ca_7781_11ea_974d_0242ac130202row13_col3 {
#             background-color:  #fff1ea;
#             color:  #000000;
#         }    #T_ae6c35ca_7781_11ea_974d_0242ac130202row13_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_ae6c35ca_7781_11ea_974d_0242ac130202row13_col5 {
#             background-color:  #fee6da;
#             color:  #000000;
#         }    #T_ae6c35ca_7781_11ea_974d_0242ac130202row14_col2 {
#             background-color:  #ffeee7;
#             color:  #000000;
#         }    #T_ae6c35ca_7781_11ea_974d_0242ac130202row14_col3 {
#             background-color:  #fff0e8;
#             color:  #000000;
#         }    #T_ae6c35ca_7781_11ea_974d_0242ac130202row14_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_ae6c35ca_7781_11ea_974d_0242ac130202row14_col5 {
#             background-color:  #fdd2bf;

# %%
nan_indices = [] 

# handle nan if there is any, it is usually a float: float('nan')

for i in range(len(unique_provinces)):
    if type(unique_provinces[i]) == float:
        nan_indices.append(i)

unique_provinces = list(unique_provinces)
province_confirmed_cases = list(province_confirmed_cases)

for i in nan_indices:
    unique_provinces.pop(i)
    province_confirmed_cases.pop(i)

# %%
china_confirmed = latest_data[latest_data['Country_Region']=='China']['Confirmed'].sum()
outside_mainland_china_confirmed = np.sum(country_confirmed_cases) - china_confirmed
plt.figure(figsize=(16, 9))
plt.barh('Mainland China', china_confirmed)
plt.barh('Outside Mainland China', outside_mainland_china_confirmed)
plt.title('Number of Covid-19 Confirmed Cases', size=20)
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

# %%
print('Outside Mainland China {} cases:'.format(outside_mainland_china_confirmed))
print('Mainland China: {} cases'.format(china_confirmed))
print('Total: {} cases'.format(china_confirmed+outside_mainland_china_confirmed))
# Out:
# Outside Mainland China 930725 cases:
# Mainland China: 82432 cases
# Total: 1013157 cases

# %%
# Only show 10 countries with the most confirmed cases, the rest are grouped into the other category
visual_unique_countries = [] 
visual_confirmed_cases = []
others = np.sum(country_confirmed_cases[10:])

for i in range(len(country_confirmed_cases[:10])):
    visual_unique_countries.append(unique_countries[i])
    visual_confirmed_cases.append(country_confirmed_cases[i])
    
visual_unique_countries.append('Others')
visual_confirmed_cases.append(others)

# %% [markdown]
# Visual Representation using bar charts and pie charts

# %%
plt.figure(figsize=(16, 9))
plt.barh(visual_unique_countries, visual_confirmed_cases, color='red')
plt.title('Number of Covid-19 Confirmed Cases in Countries/Regions', size=20)
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

# %%
# lets look at it in a logarithmic scale 
log_country_confirmed_cases = [math.log10(i) for i in visual_confirmed_cases]
plt.figure(figsize=(16, 9))
plt.barh(visual_unique_countries, log_country_confirmed_cases, color='red')
plt.title('Log of Common Log # of Covid-19 Confirmed Cases in Countries/Regions', size=20)
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

# %%
# Only show 10 provinces with the most confirmed cases, the rest are grouped into the other category
visual_unique_provinces = [] 
visual_confirmed_cases2 = []
others = np.sum(province_confirmed_cases[10:])
for i in range(len(province_confirmed_cases[:10])):
    visual_unique_provinces.append(unique_provinces[i])
    visual_confirmed_cases2.append(province_confirmed_cases[i])

visual_unique_provinces.append('Others')
visual_confirmed_cases2.append(others)

# %%
plt.figure(figsize=(16, 9))
plt.barh(visual_unique_provinces, visual_confirmed_cases2, color='red')
plt.title('Numbeer of Covid-19 Confirmed Cases in Provinces/States', size=20)
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

# %%
log_province_confirmed_cases = [math.log10(i) for i in visual_confirmed_cases2]
plt.figure(figsize=(16, 9))
plt.barh(visual_unique_provinces, log_province_confirmed_cases, color='red')
plt.title('Log of Number of Covid-19 Confirmed Cases in Provinces/States', size=20)
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

# %%
c = random.choices(list(mcolors.CSS4_COLORS.values()),k = len(unique_countries))
plt.figure(figsize=(20,15))
plt.title('Covid-19 Confirmed Cases per Country', size=20)
plt.pie(visual_confirmed_cases, colors=c)
plt.legend(visual_unique_countries, loc='best', fontsize=15)
plt.show()

# %%
c = random.sample(list(mcolors.CSS4_COLORS.values()),k = len(visual_confirmed_cases2))
plt.figure(figsize=(20,15))
plt.title('Covid-19 Confirmed Cases per State/Province/Region', size=20)
plt.pie(visual_confirmed_cases2, colors=c)
plt.legend(visual_unique_provinces, loc='best', fontsize=15)
plt.show()

# %%
# looking at US States
us_regions = list(latest_data[latest_data['Country_Region']=='US']['Province_State'].unique())
us_confirmed_cases = []
no_cases = [] 
for i in us_regions:
    cases = latest_data[latest_data['Province_State']==i]['Confirmed'].sum()
    if cases > 0:
        us_confirmed_cases.append(cases)
    else:
        no_cases.append(i)
 

for i in no_cases:
    us_regions.remove(i)
    
# only show the top 10 states
us_regions = [k for k, v in sorted(zip(us_regions, us_confirmed_cases), key=operator.itemgetter(1), reverse=True)]

for i in range(len(us_regions)):
    us_confirmed_cases[i] = latest_data[latest_data['Province_State']==us_regions[i]]['Confirmed'].sum()  

us_regions_10 = us_regions[:10]
us_regions_10.append('Others')
us_confirmed_cases_10 = us_confirmed_cases[:10]
us_confirmed_cases_10.append(np.sum(us_confirmed_cases[10:]))

# %%
c = random.sample(list(mcolors.CSS4_COLORS.values()),k = len(us_confirmed_cases))
plt.figure(figsize=(20,15))
plt.title('Covid-19 Confirmed Cases in the United States',  size=20)
plt.pie(us_confirmed_cases_10, colors=c)
plt.legend(us_regions_10, loc='best', fontsize=15)
plt.show()

# %%
# looking at Chinese provinces
china_regions = list(latest_data[latest_data['Country_Region']=='China']['Province_State'].unique())
china_confirmed_cases = []
no_cases = [] 
for i in china_regions:
    cases = latest_data[latest_data['Province_State']==i]['Confirmed'].sum()
    if cases > 0:
        china_confirmed_cases.append(cases)
    else:
        no_cases.append(i)
 

for i in no_cases:
    china_confirmed_cases.remove(i)
    
china_regions = [k for k, v in sorted(zip(china_regions, china_confirmed_cases), key=operator.itemgetter(1), reverse=True)]

for i in range(len(china_regions)):
    china_confirmed_cases[i] = latest_data[latest_data['Province_State']==china_regions[i]]['Confirmed'].sum()  

china_regions_10 = china_regions[:10]
china_regions_10.append('Others')
china_confirmed_cases_10 = china_confirmed_cases[:10]
china_confirmed_cases_10.append(np.sum(china_confirmed_cases[10:]))

# %%
c = random.sample(list(mcolors.CSS4_COLORS.values()),k = len(china_confirmed_cases))
plt.figure(figsize=(20,15))
plt.title('Covid-19 Confirmed Cases in the Mainland China', size=20)
plt.pie(china_confirmed_cases_10, colors=c)
plt.legend(china_regions_10, loc='best', fontsize=15)
plt.show()
